# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
sns.set_style('darkgrid')

# %% [markdown]
# ## Load the Dataset

# %%
df = pd.read_csv('C:\\Users\\Saumya Jain\\OneDrive\\Desktop\\dataset\\spotify.csv')
df
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0       0.01020         0.833       204600   0.434
# 1              1       0.19900         0.743       326933   0.359
# 2              2       0.03440         0.838       185707   0.412
# 3              3       0.60400         0.494       199413   0.338
# 4              4       0.18000         0.678       392893   0.561
# ...          ...           ...           ...          ...     ...
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.021900    2    0.1650    -8.795     1       0.4310  150.062
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  acousticness  danceability   duration_ms       energy  \
# count  2017.000000   2017.000000   2017.000000  2.017000e+03  2017.000000
# mean   1008.000000      0.187590      0.618422  2.463062e+05     0.681577
# std     582.402066      0.259989      0.161029  8.198181e+04     0.210273
# min       0.000000      0.000003      0.122000  1.604200e+04     0.014800
# 25%     504.000000      0.009630      0.514000  2.000150e+05     0.563000
# 50%    1008.000000      0.063300      0.631000  2.292610e+05     0.715000
# 75%    1512.000000      0.265000      0.738000  2.703330e+05     0.846000
# max    2016.000000      0.995000      0.984000  1.004627e+06     0.998000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       2017.000000  2017.000000  2017.000000  2017.000000  2017.000000
# mean           0.133286     5.342588     0.190844    -7.085624     0.612295
# ...

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.drop('Unnamed: 0',axis = 1 ,inplace = True)

# %%
df.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.0102         0.833       204600   0.434          0.021900    2
# 1        0.1990         0.743       326933   0.359          0.006110    1
# 2        0.0344         0.838       185707   0.412          0.000234    2
# 3        0.6040         0.494       199413   0.338          0.510000    5
# 4        0.1800         0.678       392893   0.561          0.512000    5
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.1650    -8.795     1       0.4310  150.062             4.0    0.286
# 1    0.1370   -10.401     1       0.0794  160.083             4.0    0.588
# 2    0.1590    -7.148     1       0.2890   75.044             4.0    0.173
# 3    0.0922   -15.236     1       0.0261   86.468             4.0    0.230
# 4    0.4390   -11.648     0       0.0694  174.004             4.0    0.904
#
#    target      song_title            artist
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   acousticness      2017 non-null   float64
#  1   danceability      2017 non-null   float64
#  2   duration_ms       2017 non-null   int64
#  3   energy            2017 non-null   float64
#  4   instrumentalness  2017 non-null   float64
#  5   key               2017 non-null   int64
#  6   liveness          2017 non-null   float64
#  7   loudness          2017 non-null   float64
#  8   mode              2017 non-null   int64
#  9   speechiness       2017 non-null   float64
#  10  tempo             2017 non-null   float64
#  11  time_signature    2017 non-null   float64
#  12  valence           2017 non-null   float64
#  13  target            2017 non-null   int64
#  14  song_title        2017 non-null   object
#  15  artist            2017 non-null   object
# ...

# %%
df.shape
# Out:
# (2017, 16)

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Top 5 most popular artists

# %%
top__five_artists = df['artist'].value_counts().head()
top__five_artists
# Out:
# artist
# Drake              16
# Rick Ross          13
# Disclosure         12
# WALK THE MOON      10
# Backstreet Boys    10
# Name: count, dtype: int64

# %%
top__five_artists.plot(kind = 'bar',rot = 0,figsize = (8,6))
# Out:
# <Axes: xlabel='artist'>

# %% [markdown]
# ### Top Five Loudest Tracks

# %%
top_five_loudest_track = df[['loudness','song_title']].sort_values(by = 'loudness',ascending = True).head()
top_five_loudest_track
# Out:
#       loudness                                         song_title
# 1594   -33.097            Lyric Pieces, Book I Op. 12: I. Arietta
# 1596   -31.367            8 Fantasiestücke, Op.12 : 1. Des Abends
# 1598   -31.082  Piano Quartet in E flat, Op.47: 3. Andante can...
# 1531   -30.447          I Was So Young, and You Were So Beautiful
# 1549   -29.460                                            Eleanor

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='loudness',y='song_title',data = top_five_loudest_track)
plt.title('Top 5 loudest track')
plt.show()

# %% [markdown]
# ### Artist with the most danceability song

# %%
top_five_artist_danceability_songs = df[['danceability','song_title','artist']].sort_values(by='danceability',ascending = False).head()
top_five_artist_danceability_songs
# Out:
#       danceability              song_title             artist
# 1433         0.984  Flashwind - Radio Edit       Ben Remember
# 1901         0.967                SexyBack  Justin Timberlake
# 604          0.962       Check Me Out Like          Blaqstarr
# 32           0.959             Best Friend         Young Thug
# 1957         0.959            Ice Ice Baby        Vanilla Ice

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='danceability',y='song_title',data = top_five_artist_danceability_songs )
plt.title('Artist with most danceability song')
plt.show()

# %% [markdown]
# ### Top 10 Instrumentalness tracks

# %%
top_ten_instrumental_tracks = df[['instrumentalness','song_title','artist']].sort_values(by='instrumentalness',ascending = False ).head()
top_ten_instrumental_tracks
# Out:
#       instrumentalness                            song_title  \
# 1313             0.976                       Senseless Order
# 271              0.968  So Destroyed (channeling Rage Peace)
# 1575             0.964             A Hundred Dreams from Now
# 1619             0.958                                 Raven
# 725              0.957                     Strandbar (disko)
#
#                   artist
# 1313  Signs of the Swarm
# 271          Prince Rama
# 1575          Ray Bryant
# 1619       John Dahlbäck
# 725           Todd Terje

# %%
plt.figure(figsize=(12, 7))


plt.pie(x=top_ten_instrumental_tracks['instrumentalness'], 
        autopct='%1.2f%%', 
        labels=top_ten_instrumental_tracks['song_title'])

plt.title('Top 10 Instrumental Tracks')
plt.show()

# %% [markdown]
#  ### Top 10 Energetic tracks

# %%
top_ten_energetic_tracks = df[['energy','song_title','artist']].sort_values(by='energy',ascending = False ).head()
top_ten_energetic_tracks
# Out:
#       energy         song_title                    artist
# 1299   0.998      No Absolution         Thy Art Is Murder
# 1322   0.997         Pitchblack  Walking Dead On Broadway
# 1297   0.994  A Darkened Gospel      A Wake in Providence
# 1347   0.993         Unanswered           Suicide Silence
# 1332   0.992    Beautiful Agony          Within The Ruins

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='artist',y='energy',data = top_ten_energetic_tracks)
plt.title('Artist with most Energetic song')
plt.show()
